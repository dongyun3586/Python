# %%
import requests
from bs4 import BeautifulSoup

url = 'http://www.riss.kr/search/Search.do?isDetailSearch=N&searchGubun=true&viewYn=OP&queryText=&strQuery=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5+%EA%B5%90%EC%9C%A1&exQuery=&exQueryText=&order=%2FDESC&onHanja=false&strSort=RANK&p_year1=&p_year2=&iStartCount=0&orderBy=&mat_type=&mat_subtype=&fulltext_kind=&t_gubun=&learning_type=&ccl_code=&inside_outside=&fric_yn=&image_yn=&gubun=&kdc=&ttsUseYn=&l_sub_code=&fsearchMethod=search&sflag=1&isFDetailSearch=N&pageNumber=1&resultKeyword=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5+%EA%B5%90%EC%9C%A1&fsearchSort=&fsearchOrder=&limiterList=&limiterListText=&facetList=&facetListText=&fsearchDB=&icate=bib_t&colName=bib_t&pageScale=100&isTab=Y&regnm=&dorg_storage=&language=&language_code=&clickKeyword=&relationKeyword=&query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5+%EA%B5%90%EC%9C%A1' 
res = requests.get(url)

print(res.status_code)
res.raise_for_status()
soup = BeautifulSoup(res.text, 'lxml')

cont = soup.find('div', attrs={'class':'srchResultListW'}).ul
rows = cont.find_all('li')
    
for row in rows:
    # 논문 리스트 번호
    num = row.find('span', attrs={'class':'num'})
    if num:
        num = num.get_text().strip()
    else:
        continue
    
    # 논문 제목
    title = row.find('p', attrs={'class':'title'})
    title = row.a.get_text()
    
    # 기타 등등
    etc = row.find('p', attrs={'class':'etc'})
    etc = etc.find_all('span')
    writer = etc[0].a.get_text()                    # 논문 저자
    assigned = etc[1].a.get_text()                  # 승인 기관
    year = etc[2].get_text()                        # 년도
    degree = etc[3].get_text()                      # 학위
    
    print(num, title, writer, assigned, year, degree)
    

# for i in range(0, 100, 100):

# %%
import requests
from bs4 import BeautifulSoup

for i in range(0, 900, 100):
    url = 'http://www.riss.kr/search/Search.do?isDetailSearch=N&searchGubun=true&viewYn=OP&queryText=&strQuery=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5+%EA%B5%90%EC%9C%A1&exQuery=&exQueryText=&order=%2FDESC&onHanja=false&strSort=RANK&p_year1=&p_year2=&iStartCount={}&orderBy=&mat_type=&mat_subtype=&fulltext_kind=&t_gubun=&learning_type=&ccl_code=&inside_outside=&fric_yn=&image_yn=&gubun=&kdc=&ttsUseYn=&l_sub_code=&fsearchMethod=search&sflag=1&isFDetailSearch=N&pageNumber=1&resultKeyword=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5+%EA%B5%90%EC%9C%A1&fsearchSort=&fsearchOrder=&limiterList=&limiterListText=&facetList=&facetListText=&fsearchDB=&icate=bib_t&colName=bib_t&pageScale=100&isTab=Y&regnm=&dorg_storage=&language=&language_code=&clickKeyword=&relationKeyword=&query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5+%EA%B5%90%EC%9C%A1'.format(i)
    res = requests.get(url)

    # print(res.status_code)
    res.raise_for_status()
    soup = BeautifulSoup(res.text, 'lxml')

    cont = soup.find('div', attrs={'class':'srchResultListW'}).ul
    rows = cont.find_all('li')
        
    for row in rows:
        # 논문 리스트 번호
        num = row.find('span', attrs={'class':'num'})
        if num:
            num = num.get_text().strip()
        else:
            continue
        
        # 논문 제목
        title = row.find('p', attrs={'class':'title'})
        title = row.a.get_text()
        
        # 기타 등등
        etc = row.find('p', attrs={'class':'etc'})
        etc = etc.find_all('span')
        writer = etc[0].a.get_text()                    # 논문 저자
        assigned = etc[1].a.get_text()                  # 승인 기관
        year = etc[2].get_text()                        # 년도
        degree = etc[3].get_text()                      # 학위
        
        print(num, title, writer, assigned, year, degree)
        

    # for i in range(0, 100, 100):
# Out:
# 200
# 1 인공지능 윤리를 강조한 인공지능교육 프로그램이 인공지능 윤리의식과 창의적 문제해결력에 미치는 영향 박지민 이화여자대학교 대학원 2021 국내석사
# 2 스토리텔링 기반의 인공지능 교육프로그램 개발 박채은 경인교육대학교 교육전문대학원 2021 국내석사
# 3 디자인 씽킹 기반의 초등학교 인공지능교육프로그램 프로토타입 개발 김영재 부산대학교 대학원 2021 국내석사
# 4 초등학생을 위한 인공지능윤리교육 STEAM 프로그램 개발 김지언 경인교육대학교 교육전문대학원 2021 국내석사
# 5 인공지능 리터러시 기반의 설명가능한 인공지능 교육 프로그램 개발 정기민 경인교육대학교 교육전문대학원 2021 국내석사
# 6 Chinese Teachers’ Perceptions on the Use of AI-based Education Platform 유강동 서울대학교 대학원 2021 국내석사
# 7 초등학교 인공지능교육을 위한 언플러그드 교육 프로그램 개발 : 제약만족문제를 중심으로 장명현 경인교육대학교 교육전문대학원 2020 국내석사
# 8 언플러그드 활동과 머신러닝 사이트를 활용한 중학교의 인공지능 교육 프로그램 개발 구정화 전남대학교 대학원 2020 국내석사
# 9 초등 교사를 위한 인공지능교육 교사연수프로그램 개발 고병철 경인교육대학교 교육전문대학원 2021 국내석사
# 10 인공지능교육 관련 연구 동향 분석 : 키워드 네트워크 분석 한지윤 경인교육대학교 교육전문대학원 2021 국내석사
# 11 인공지능 시대의 중등 교육 : 실태조사 및 제안 유채은 전남대학교 2021 국내석사
# 12 파이썬 기반의 초등학교 인공지능교육 프로그램 개발과 효과 연구 : 머신러닝을 중심으로 심수환 대구교육대학교 교육대학원 2021 국내석사
# 13 인공지능과 스마트팜을 이용한 초등 발명교육 프로그램 개발 김정훈 서울교육대학교 대학원 2021 국내석사
# 14 Jetson Nano와 3D프린터를 이용한 인공지능 교육용 키트 제작 박성주 호남대학교대학원 2021 국내석사
# 15 온택트 기반 초등 인공지능 소양 교육 프로그램 개발 및 적용 : Development and application of AI literacy education program for elementary school students based on On:tact 김선미 서울교육대학교 교육전문대학원 2021 국내석사
# 16 초등학생을 위한 직업 연계형 인공지능 교육 프로그램의 개발 및 적용 박혁거세 서울교육대학교 교육전문대학원 2021 국내석사
# 17 프로젝트기반 인공지능 윤리교육 프로그램 개발 배진아 제주대학교 2020 국내석사
# 18 전문가 시스템 중심의 인공지능 융합교육 프로그램 개발 이정진 경인교육대학교 교육전문대학원 2020 국내석사
# 19 중국의 융합인재교육(STEAM) 기반 인공지능 교육과정과 교과서 내용 분석 양환근 한국교원대학교 2020 국내석사
# 20 초등학교 인공지능 수업을 위한 언플러그드 교육 프로그램 개발 장연주 서울교육대학교 교육전문대학원 2019 국내석사
# 21 인공지능 기술 활용 지구시민교육을 통한 지속가능성 소양의 함양 조현기 서울교육대학교 교육전문대학원 2021 국내박사
# 22 인공지능시대 기독교 노인교육의 방향 박성일 목원대학교 2020 국내석사
# 23 인공지능시대 융복합적 성서교육모형 연구 최은택 연세대학교 대학원 2019 국내박사
# 24 블렌디드학습 기반 인공지능 윤리교육 프로그램 개발 김은혜 서울교육대학교 교육전문대학원 2021 국내석사
# 25 초등학생의 인공지능 리터러시 신장을 위한 교육 프로그램 개발 및 적용 서승희 서울교육대학교 교육전문대학원 2021 국내석사
# 26 규칙 기반 시스템을 활용한 인공지능 교육 프로그램 개발 및 적용 서상은 서울교육대학교 교육전문대학원 2021 국내석사
# 27 주요국가 사례를 반영한 인공지능 교육 방향 제안 및 교재검토 김성환 전북대학교 교육대학원 2021 국내석사
# 28 노벨엔지니어링을 활용한 인공지능 교육프로그램 개발 김주현 서울교육대학교 교육전문대학원 2020 국내석사
# 29 2015 개정 교육과정에 따른 고등학교 인공지능 교과서 분석 및 평가 김지은 고려대학교 교육대학원 2021 국내석사
# 30 역량기반 인공지능 교육 모델 설계 및 적용 유한종 서울교육대학교 교육전문대학원 2020 국내석사
# 31 Raspberry Pi 4와 Python을 사용한 인공지능 교육용 신경회로망 구현 SW 신예림 이화여자대학교 교육대학원 2020 국내석사
# 32 선형 회귀 모델 기반의 인공지능 예측 시스템을 이해하기 위한 초등학생용 교육 프로그램의 개발 이수정 대구교육대학교 교육대학원 2021 국내석사
# 33 초등학교 인공지능 교육을 위한 EPM 학습 모형 개발 및 적용 문종현 서울교육대학교 교육전문대학원 2021 국내석사
# 34 인공지능을 활용한 앱인벤터 소프트웨어 교육 수업 설계 및 적용 : : 블랜디드 수업방식 중심으로 박미희 경인교육대학교 교육전문대학원 2021 국내석사
# 35 인공지능 기반 미술을 중심으로 한 미술비평교육이 고등학생의 미디어 리터러시에 미치는 영향 김예진 이화여자대학교 교육대학원 2021 국내석사
# 36 초등학교 인공지능 융합교육을 위한 2ADE 교수설계 모형 개발 및 적용 김예슬 서울교육대학교 교육전문대학원 2021 국내석사
# 37 인공지능 스피커를 활용한 언어교육에서 교수자의 스캐폴딩 전략 개발 홍수민 서울대학교 대학원 2021 국내석사
# 38 인공지능 리터러시 향상을 위한 앱 개발 초등 교육 프로그램 김성주 서울교육대학교 교육전문대학원 2021 국내석사
# 39 SW교육과 연계한 초등학생 인공지능 언플러그드 교육 프로그램 개발 정미연 경인교육대학교 교육전문대학원 2021 국내석사
# 40 챗봇 기반 인공지능 교육 프로그램 개발과 적용 한민영 경인교육대학교 교육전문대학원 2021 국내석사
# 41 중학교 자유학기제를 위한 인공지능 교육 프로그램 개발 이규화 한국교원대학교 대학원 2021 국내석사
# 42 NCS 기반의 직업교육훈련 운영 개선방안에 관한 연구 : 인공지능 인력양성 중심으로 문성연 전남대학교 2021 국내석사
# 43 인공지능(AI) 융합 소프트웨어 교육이 초등학생의 컴퓨팅 사고력에 미치는 영향 김광수 한국교원대학교 교육대학원 2021 국내석사
# 44 웹 플랫폼을 활용한 초등 인공지능 교육 프로그램 개발 강수현 서울교육대학교 대학원 2021 국내석사
# 45 인공지능 기반 도구를 활용한 미세먼지 환경교육 프로그램이 초등학생의 환경감수성과 자기효능감에 미치는 영향 최일훈 부산교육대학교 교육대학원 2021 국내석사
# 46 인공지능시대의 비대면·온라인 기독교교육 모형 연구 조은애 연세대학교 연합신학대학원 2021 국내석사
# 47 인공지능의 교육적 활용을 위한 수업모형 연구 : 수학교과 과목 사례 중심 심승섭 인천대학교 교육대학원 2019 국내석사
# 48 웹기반의 스마트교육용 인공지능 마이크시스템 연구 남기복 공주대학교 일반대학원 2020 국내박사
# 49 인공지능 시대의 예술 : Google A.I. Experiments를 활용한 통합예술 교육 방안 박수빈 공주대학교 2017 국내석사
# 50 중국 인공지능 활용 교육용 앱에 대한 중학생, 학부모, 교사의 인식 비교 진엽 동국대학교 2020 국내석사
# 51 제 4차 산업혁명시대의 초등학생을 위한 창의교육 프로그램 개발 및 적용: 인공지능과 드론을 중심으로 김푸름 제주대학교 교육대학원 2019 국내석사
# 52 추천 시스템 기반 초등학생 인공지능 교육 프로그램의 개발 및 적용 이선진 제주대학교 교육대학원 2018 국내석사
# 53 인공지능 융합교육을 위한 교원의 역량 도출 박한별 고려대학교 교육대학원 2021 국내석사
# 54 초등학생을 위한 활동중심 인공지능 융합 교육 프로그램 개발 및 적용 신진선 청주교육대학교 대학원 2020 국내석사
# 55 인공지능의 敎育的 適用에 대한 연구 강연전 弘益大學校 1992 국내석사
# 56 중등 수학 교육에 있어서 인공지능 컴퓨터 보조 학습 지도에 관한 연구 박일영 경성대학교 교육대학원 1996 국내석사
# 57 정보전문가 양성을 위한 교육과정에 관한 연구 : 인공지능과 전문가시스템 교육과정 분석 박미영 서울여자대학교 1997 국내석사
# 58 인공지능 시대의 새로운 교육패러다임에 대한 연구 김지원 경북대학교 대학원 2017 국내박사
# 59 인공지능 기반 가상현실 활용 킬러 콘텐츠 개발 연구 : 교육, 게임, 쇼핑 콘텐츠를 중심으로 이주희 호서대학교 2018 국내석사
# 60 Teachable machine을 활용한 초등학교 인공지능 체험 프로그램 개발 및 적용 이승미 서울교육대학교 교육전문대학원 2021 국내석사
# 61 플립 러닝을 적용한 텐서플로 활용 인공지능 데이터분석 수업 교안 설계 김병진 인천대학교 교육대학원 2020 국내석사
# 62 인공지능기술과 인간의 책임 연구 : 한스 요나스의 관점에서 김도윤 제주대학교 2020 국내석사
# 63 중국 K-12  인공지능 교재 분석 김은경 韓國外國語大學校 敎育大學院 2021 국내석사
# 64 학습자 몰입(engagement) 이론 기반 초등영어 학습목적형 인공지능 챗봇 개발 및 교수·학습 설계 원리 이삭 서울교육대학교 교육전문대학원 2021 국내박사
# 65 Arduino ESP-32 IDE 기반 인공 신경 회로망 구현 기술의 교육방법 이미근 이화여자대학교 교육대학원 2020 국내석사
# 66 백워드 설계 모형을 적용한 자유학년제 인공지능 주제선택 활동 개발 강남선 성균관대학교 일반대학원 2021 국내석사
# 67 인공지능 윤리의식 검사 도구 개발 및 적용 김귀식 경인교육대학교 교육전문대학원 2021 국내석사
# 68 연상 키워드를 기반으로 한 초등교사의 인공지능 관련 인식 분석 정슬기 서울교육대학교 교육전문대학원 2020 국내석사
# 69 인공지능 채팅프로그램이 고등학생의 영어 쓰기 능력 및 정의적 측면에 미치는 영향 연구 신형정 이화여자대학교 대학원 2002 국내석사
# 70 디지로그 기법 활용 초등 인공지능 핵심 원리 교수·학습 프로그램 개발 황유리 제주대학교 대학원 2021 국내석사
# 71 인공지능 기술 발전에 따른 회계인재 육성과 발전 방향 장려령 전북대학교 일반대학원 2019 국내석사
# 72 Micro:bit 활용한 인공신경회로망 교육용 컨텐츠 설계 이경미 이화여자대학교 교육대학원 2020 국내석사
# 73 4차 산업혁명 시대의 다차원 지능 개발 지향 교육 개혁 방안 이경 고려대학교 행정전문대학원 2021 국내석사
# 74 인공지능(AI) 음성인식 스피커를 활용한 가정에서의 유아 대상 상호작용 영어 학습모형 개발에 관한 연구 황정혜 고려대학교 대학원 2020 국내박사
# 96 지능 개발을 위한 교육용 소프트웨어 개발에 관한 연구 신우진 단국대학교 1996 국내박사
# 97 디자인씽킹 프로세스 기반의 메이커교육 프로그램 개발 및 적용 : 감성지능의 효과를 중심으로 유예은 경희대학교 대학원 2018 국내석사
# 98 인공지능 작곡 프로그램의 발전 방향의 연구 김진하 상명대학교 일반대학원 2021 국내석사
# 99 인공지능(AI) 기능이 e-러닝 프로그램 성과에 미친 영향 분석 신현태 건국대학교 2018 국내석사
# 100 행위자네트워크이론과 체화된 인지 이론으로 본 인공지능 시대의 지식과 학습의 개념에 대한 탐구 설동준 한양대학교 대학원 2018 국내석사
# 200
# 101 당신이 원하던 인공지능이 맞습니까? : slid & liquid : A.I. design fiction 장소희 홍익대학교 대학원 2019 국내석사
# 102 인공지능 로봇에 의한 행정과 국가배상책임제도에 관한 연구 이지헌 성균관대학교 2018 국내석사
# 103 인공지능(Artificial Intelligence)의 발달이 디자인 직군에 미치는 영향 연구 : 디자이너의 미래지향적 사회기여도와 핵심역량 중심으로 전영준 홍익대학교 대학원 2018 국내석사
# 104 SNS 정보 기반의 인공지능 챗봇 플랫폼 설계 및 구현 이대근 전남대학교 2019 국내박사
# 105 인공지능에 관한 법적 규율방안 : 인공지능 알고리즘과 빅데이터의 법적규율을 중심으로 임경숙 한양대학교 법학전문대학 2019 국내박사
# 106 4차 산업혁명 시대의 영성지능 함양을 위한 기독교교육 김미향 장로회신학대학교 대학원 2020 국내석사
# 107 Study on User Experience with Mimicked Persona of Conversational AI in Daily Healthcare Youjin Hwang 서울대학교 대학원 2021 국내박사
# 108 지능정보시대 수학교육의 방향 : 2015년 개정 수학 교육과정을 중심으로 임수정 상명대학교 교육대학원 2019 국내석사
# 109 인공지능(AI)기술 기반 융복합 인터랙티브 무용공연콘텐츠 설계 및 구현 박진영 한양대학교 대학원 2021 국내박사
# 110 초등 영어 학습자의 인공지능 채터봇을 활용한 채팅에 관한 연구 : 사립 초등학교 6학년을 대상으로 박미정 연세대학교 교육대학원 2010 국내석사
# 111 인공지능에 대한 논증에서 나타나는 학생들의 생명개념 인식 탐색 : 초등학생과 고등학생의 사례를 중심으로 은빛나래 전북대학교 교육대학원 2020 국내석사
# 112 인공지능을 활용한 대규모 챗봇 구축 방법론 연구 권종진 건국대학교 2020 국내석사
# 113 미술관의 공공성 의미와 확장에  관한 연구 : 미술관 민영화에서 인공지능 시대의 공공성 논의까지 안필연 동덕여자대학교 2020 국내박사
# 114 인공지능 바둑프로그램 참여 동기가 초등학생의 학업적 그릿과 대인관계 성향에 미치는 영향 김기범 전남대학교 2021 국내석사
# 115 국내 HRD 담당자의 인공지능(AI) 시스템 수용의도에 영향을 미치는 요인 연구 : 통합기술수용이론(UTAUT)을 중심으로 문미라 고려대학교 교육대학원 2021 국내석사
# 116 인공지능을 活用한 MICE産業의 變化와 트랜드 : 인공지능을 활용한 MICE산업의 변화와 트렌드에 관한 인식 연구 이윤정 동신대학교 일반대학 2021 국내석사
# 829 RNN을 이용한 수강후기 분석 황진경 한국방송통신대학교 대학원 2018 국내석사
# 830 Development and validation of a visually explainable deep learning model for detection of C-shaped canals of the mandibular second molars in dental radiographs 양수진 Graduate School, Yonsei University 2021 국내박사
# 831 중국 경제성장이 고용에 미치는 영향 분석 지앙사오이 청주대학교 대학원 2019 국내석사
# 832 서비스디자인을 활용한 스마트팜 활성화를 위한 연구 : 도시농업을 위한 식물재배시스템을 중심으로 김창훈 한국산업기술대학교 산업기술·경영대학원 2019 국내석사
# 833 自律走行車 商用化에 따른 安全性 改善 事項 提言 김유미 성균관대학교 정보통신대학원 2020 국내석사
# 834 디지털 혁신기술에 대한 수용 의도가  업무성과에 미치는 영향 연구 : N은행을 중심으로 박미정 공주대학교 일반대학원 2020 국내석사
# 835 컴퓨터 코스웨어 개발방법에 관한 연구 : 코복 언어 학습 중심으로 조용각 한양대학교 산업대학원 1993 국내석사
# 836 공항의 서비스 로봇 품질 지각이 공항 브랜드이미지에 미치는 영향에 관한 연구 탕기박 상명대학교 일반대학원 2019 국내석사
# 837 미디어 생태계 변화에 따른 미디어플랫폼 산업경쟁력 분석에 관한 연구 : 시스템다이내믹스 방법론을 중심으로 박란 경기대학교 대학원 2020 국내박사
# 838 Stereo Image 및 Deep learning 기반 3D 위치파악 알고리즘 연구 신상훈 국민대학교 일반대학원 2021 국내석사
# 839 코치의 커뮤니케이션 특성이 코칭고객의 긍정심리자본에 미치는 영향 배용관 국민대학교 일반대학원 2020 국내박사
# 840 박정희체제의 사운드스케이프와 문학의 대응 임태훈 성균관대학교 2014 국내박사
# 841 문화복지 실천을 통한 지역사회 선교연구 양문섭 장로회신학대학교 2019 국내박사
# 842 OSD를 이용한 DTV 수신모듈용 게임 설계 및 구현 김장현 전남대학교 대학원 2011 국내석사
# 843 4차산업혁명 시대의 가상공간(Cyberspace)  문화에 대한 선교 상황화(Contextualization) 연구 박남주 총신대학교 선교대학원 2021 국내석사
# 844 편재적 컴퓨팅에서의 TUI(tangible user interface) 디자인 활용에 관한 연구 : 어린이용 TUI 디자인 연구를 중심으로 최재희 漢陽大學校 2007 국내박사
# 845 군내 상시 예방감사 시스템 구축방안에 관한 연구 노학산 우석대학교 국방정책대학원 2021 국내석사
# 846 국내은행 RPA 운영현황 및 효율적 운영 조직에 대한 연구 주동희 동아대학교 대학원 2021 국내석사
# 847 신경망 기반 주가 예측 시스템의 성능평가 요소 분석 김현진 성신여자대학교 2005 국내석사
# 848 미적 창작물을 통해서 바라본 난독증에 대한 고찰 정두연 고려대학교 2018 국내석사
# 849 소 행동 인식 및 발정 탐지 안성진 한국기술교육대학교 2018 국내석사

# %%
# 인공지능관련 논문 검색 - 국내 학위 논문
import requests
from bs4 import BeautifulSoup
import csv

# 1. csv 파일 생성
file_name = 'aipaper.csv'
f = open(file_name, 'w', encoding='utf-8-sig', newline='')
csv_writer = csv.writer(f)

for i in range(0, 900, 100):
    url = 'http://www.riss.kr/search/Search.do?isDetailSearch=N&searchGubun=true&viewYn=OP&queryText=&strQuery=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5+%EA%B5%90%EC%9C%A1&exQuery=&exQueryText=&order=%2FDESC&onHanja=false&strSort=RANK&p_year1=&p_year2=&iStartCount={}&orderBy=&mat_type=&mat_subtype=&fulltext_kind=&t_gubun=&learning_type=&ccl_code=&inside_outside=&fric_yn=&image_yn=&gubun=&kdc=&ttsUseYn=&l_sub_code=&fsearchMethod=search&sflag=1&isFDetailSearch=N&pageNumber=1&resultKeyword=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5+%EA%B5%90%EC%9C%A1&fsearchSort=&fsearchOrder=&limiterList=&limiterListText=&facetList=&facetListText=&fsearchDB=&icate=bib_t&colName=bib_t&pageScale=100&isTab=Y&regnm=&dorg_storage=&language=&language_code=&clickKeyword=&relationKeyword=&query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5+%EA%B5%90%EC%9C%A1'.format(i)
    res = requests.get(url)

    # print(res.status_code)
    res.raise_for_status()
    soup = BeautifulSoup(res.text, 'lxml')

    cont = soup.find('div', attrs={'class':'srchResultListW'}).ul
    rows = cont.find_all('li')
        
    for row in rows:
        # 논문 리스트 번호
        num = row.find('span', attrs={'class':'num'})
        if num:
            num = num.get_text().strip()
        else:
            continue
        
        # 논문 제목
        title = row.find('p', attrs={'class':'title'})
        # 링크
        link = 'http://www.riss.kr' + title.find('a')['href']
        
        title = row.a.get_text()
        
        
        
        # 기타 등등
        etc = row.find('p', attrs={'class':'etc'})
        etc = etc.find_all('span')
        writer = etc[0].a.get_text()                    # 논문 저자
        assigned = etc[1].a.get_text()                  # 승인 기관
        year = etc[2].get_text()                        # 년도
        degree = etc[3].get_text()                      # 학위
        
        # print(num, title, writer, assigned, year, degree, link)
        # 논문 제목에 '인공지능' 키워드가 없는 것 제외
        if '인공지능' not in title:
            continue
        csv_writer.writerow([num, title, writer, assigned, year, degree, link])  

f.close()

# %%
# 머신러닝관련 논문 검색 - 국내 학위 논문
import requests
from bs4 import BeautifulSoup
import csv

# 1. csv 파일 생성
file_name = 'aipaper.csv'
f = open(file_name, 'w', encoding='utf-8-sig', newline='')
csv_writer = csv.writer(f)

for i in range(0, 900, 100):
    url = 'http://www.riss.kr/search/Search.do?isDetailSearch=N&searchGubun=true&viewYn=OP&queryText=&strQuery=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D+%EA%B5%90%EC%9C%A1&exQuery=&exQueryText=&order=%2FDESC&onHanja=false&strSort=RANK&p_year1=&p_year2=&iStartCount={}&orderBy=&mat_type=&mat_subtype=&fulltext_kind=&t_gubun=&learning_type=&ccl_code=&inside_outside=&fric_yn=&image_yn=&gubun=&kdc=&ttsUseYn=&l_sub_code=&fsearchMethod=search&sflag=1&isFDetailSearch=N&pageNumber=1&resultKeyword=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D+%EA%B5%90%EC%9C%A1&fsearchSort=&fsearchOrder=&limiterList=&limiterListText=&facetList=&facetListText=&fsearchDB=&icate=bib_t&colName=bib_t&pageScale=100&isTab=Y&regnm=&dorg_storage=&language=&language_code=&clickKeyword=&relationKeyword=&query=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D+%EA%B5%90%EC%9C%A1'.format(i)
    res = requests.get(url)

    # print(res.status_code)
    res.raise_for_status()
    soup = BeautifulSoup(res.text, 'lxml')

    cont = soup.find('div', attrs={'class':'srchResultListW'}).ul
    rows = cont.find_all('li')
        
    for row in rows:
        # 논문 리스트 번호
        num = row.find('span', attrs={'class':'num'})
        if num:
            num = num.get_text().strip()
        else:
            continue
        
        # 논문 제목
        title = row.find('p', attrs={'class':'title'})
        # 링크
        link = 'http://www.riss.kr' + title.find('a')['href']
        
        title = row.a.get_text()
        
        
        
        # 기타 등등
        etc = row.find('p', attrs={'class':'etc'})
        etc = etc.find_all('span')
        writer = etc[0].a.get_text()                    # 논문 저자
        assigned = etc[1].a.get_text()                  # 승인 기관
        year = etc[2].get_text()                        # 년도
        degree = etc[3].get_text()                      # 학위
        
        # print(num, title, writer, assigned, year, degree, link)
        # 논문 제목에 '머신러닝' 키워드가 없는 것 제외
        if '머신러닝' not in title:
            continue
        csv_writer.writerow([num, title, writer, assigned, year, degree, link])  

f.close()

# %%
# 인공지능관련 논문 검색 - 국내 학술 논문
import requests
from bs4 import BeautifulSoup
import csv

# 1. csv 파일 생성
file_name = 'aipaper.csv'
f = open(file_name, 'w', encoding='utf-8-sig', newline='')
csv_writer = csv.writer(f)

for i in range(0, 1500, 100):
    url = 'http://www.riss.kr/search/Search.do?isDetailSearch=N&searchGubun=true&viewYn=OP&queryText=&strQuery=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5+%EA%B5%90%EC%9C%A1&exQuery=&exQueryText=&order=%2FDESC&onHanja=false&strSort=RANK&p_year1=&p_year2=&iStartCount={}&orderBy=&mat_type=&mat_subtype=&fulltext_kind=&t_gubun=&learning_type=&ccl_code=&inside_outside=&fric_yn=&image_yn=&gubun=&kdc=&ttsUseYn=&l_sub_code=&fsearchMethod=search&sflag=1&isFDetailSearch=N&pageNumber=1&resultKeyword=&fsearchSort=&fsearchOrder=&limiterList=&limiterListText=&facetList=&facetListText=&fsearchDB=&icate=re_a_kor&colName=re_a_kor&pageScale=100&isTab=Y&regnm=&dorg_storage=&language=&language_code=&clickKeyword=&relationKeyword=&query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5+%EA%B5%90%EC%9C%A1'.format(i)
    res = requests.get(url)

    # print(res.status_code)
    res.raise_for_status()
    soup = BeautifulSoup(res.text, 'lxml')

    cont = soup.find('div', attrs={'class':'srchResultListW'}).ul
    if not cont:
        continue
    rows = cont.find_all('li')
        
    for row in rows:
        # 논문 리스트 번호
        num = row.find('span', attrs={'class':'num'})
        if num:
            num = num.get_text().strip()
        else:
            continue
        
        # 논문 제목
        title = row.find('p', attrs={'class':'title'})
        if not title:
            continue
        # 링크
        link = 'http://www.riss.kr' + title.find('a')['href']
        
        title = row.a.get_text()
        
        
        
        # 기타 등등
        etc = row.find('p', attrs={'class':'etc'})
        etc = etc.find_all('span')
        if not etc:
            continue
        writer = etc[0].a.get_text()                    # 논문 저자
        assigned = etc[1].a.get_text()                  # 승인 기관
        year = etc[2].get_text()                        # 년도
        degree = etc[3].get_text()                      # 학위
        
        # print(num, title, writer, assigned, year, degree, link)
        # 논문 제목에 '인공지능' 키워드가 없는 것 제외
        if '인공지능' not in title:
            continue
        csv_writer.writerow([num, title, writer, assigned, year, degree, link])  

f.close()

# %%
# 머신러닝관련 논문 검색 - 국내 학술 논문
import requests
from bs4 import BeautifulSoup
import csv

# 1. csv 파일 생성
file_name = 'aipaper.csv'
f = open(file_name, 'w', encoding='utf-8-sig', newline='')
csv_writer = csv.writer(f)

for i in range(0, 1800, 100):
    url = 'http://www.riss.kr/search/Search.do?isDetailSearch=N&searchGubun=true&viewYn=OP&queryText=&strQuery=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D+%EA%B5%90%EC%9C%A1&exQuery=&exQueryText=&order=%2FDESC&onHanja=false&strSort=RANK&p_year1=&p_year2=&iStartCount={}&orderBy=&mat_type=&mat_subtype=&fulltext_kind=&t_gubun=&learning_type=&ccl_code=&inside_outside=&fric_yn=&image_yn=&gubun=&kdc=&ttsUseYn=&l_sub_code=&fsearchMethod=search&sflag=1&isFDetailSearch=N&pageNumber=1&resultKeyword=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D+%EA%B5%90%EC%9C%A1&fsearchSort=&fsearchOrder=&limiterList=&limiterListText=&facetList=&facetListText=&fsearchDB=&icate=re_a_kor&colName=re_a_kor&pageScale=10&isTab=Y&regnm=&dorg_storage=&language=&language_code=&clickKeyword=&relationKeyword=&query=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D+%EA%B5%90%EC%9C%A1'.format(i)
    res = requests.get(url)

    # print(res.status_code)
    res.raise_for_status()
    soup = BeautifulSoup(res.text, 'lxml')

    cont = soup.find('div', attrs={'class':'srchResultListW'}).ul
    if not cont:
        continue
    rows = cont.find_all('li')
        
    for row in rows:
        # 논문 리스트 번호
        num = row.find('span', attrs={'class':'num'})
        if num:
            num = num.get_text().strip()
        else:
            continue
        
        # 논문 제목
        title = row.find('p', attrs={'class':'title'})
        if not title:
            continue
        # 링크
        link = 'http://www.riss.kr' + title.find('a')['href']
        
        title = row.a.get_text()
        
        
        
        # 기타 등등
        etc = row.find('p', attrs={'class':'etc'})
        etc = etc.find_all('span')
        if not etc:
            continue
        writer = etc[0].a.get_text()                    # 논문 저자
        assigned = etc[1].a.get_text()                  # 승인 기관
        year = etc[2].get_text()                        # 년도
        degree = etc[3].get_text()                      # 학위
        
        # print(num, title, writer, assigned, year, degree, link)
        # 논문 제목에 '머신러닝' 키워드가 없는 것 제외
        if '머신러닝' not in title:
            continue
        csv_writer.writerow([num, title, writer, assigned, year, degree, link])  

f.close()

# %%
# 정보영재관련 논문 검색 - 국내학술논문
import requests
from bs4 import BeautifulSoup
import csv

# 1. csv 파일 생성
file_name = 'aipaper.csv'
f = open(file_name, 'w', encoding='utf-8-sig', newline='')
csv_writer = csv.writer(f)

for i in range(0, 800, 100):
    url = 'http://www.riss.kr/search/Search.do?isDetailSearch=N&searchGubun=true&viewYn=OP&queryText=&strQuery=%EB%A8%B8%EC%8B%A0%EB%9F%AC%EB%8B%9D+%EA%B5%90%EC%9C%A1&exQuery=&exQueryText=&order=%2FDESC&onHanja=false&strSort=RANK&p_year1=&p_year2=&iStartCount={}&orderBy=&mat_type=&mat_subtype=&fulltext_kind=&t_gubun=&learning_type=&ccl_code=&inside_outside=&fric_yn=&image_yn=&gubun=&kdc=&ttsUseYn=&l_sub_code=&fsearchMethod=search&sflag=1&isFDetailSearch=N&pageNumber=1&resultKeyword=&fsearchSort=&fsearchOrder=&limiterList=&limiterListText=&facetList=&facetListText=&fsearchDB=&icate=re_a_kor&colName=re_a_kor&pageScale=10&isTab=Y&regnm=&dorg_storage=&language=&language_code=&clickKeyword=&relationKeyword=&query=%EC%A0%95%EB%B3%B4%EC%98%81%EC%9E%AC'.format(i)
    res = requests.get(url)

    # print(res.status_code)
    res.raise_for_status()
    soup = BeautifulSoup(res.text, 'lxml')

    cont = soup.find('div', attrs={'class':'srchResultListW'}).ul
    if not cont:
        continue
    rows = cont.find_all('li')
        
    for row in rows:
        # 논문 리스트 번호
        num = row.find('span', attrs={'class':'num'})
        if num:
            num = num.get_text().strip()
        else:
            continue
        
        # 논문 제목
        title = row.find('p', attrs={'class':'title'})
        if not title:
            continue
        # 링크
        link = 'http://www.riss.kr' + title.find('a')['href']
        
        title = row.a.get_text()
        
        
        
        # 기타 등등
        etc = row.find('p', attrs={'class':'etc'})
        etc = etc.find_all('span')
        if not etc:
            continue
        writer = etc[0].a.get_text()                    # 논문 저자
        if etc[1].a:
            assigned = etc[1].a.get_text()                  # 승인 기관
        else:
            continue
        
        year = etc[2].get_text()                        # 년도
        degree = etc[3].get_text()                      # 학위
        
        # print(num, title, writer, assigned, year, degree, link)
        # 논문 제목에 '머신러닝' 키워드가 없는 것 제외
        if '영재' not in title:
            continue
        csv_writer.writerow([num, title, writer, assigned, year, degree, link])  

f.close()

# %%
# 정보영재관련 논문 검색 - 국내학위논문
import requests
from bs4 import BeautifulSoup
import csv

# 1. csv 파일 생성
file_name = 'aipaper.csv'
f = open(file_name, 'w', encoding='utf-8-sig', newline='')
csv_writer = csv.writer(f)

for i in range(0, 900, 100):
    url = 'http://www.riss.kr/search/Search.do?isDetailSearch=N&searchGubun=true&viewYn=OP&queryText=&strQuery=%EC%A0%95%EB%B3%B4%EC%98%81%EC%9E%AC&exQuery=&exQueryText=&order=%2FDESC&onHanja=false&strSort=RANK&p_year1=&p_year2=&iStartCount={}&orderBy=&mat_type=&mat_subtype=&fulltext_kind=&t_gubun=&learning_type=&ccl_code=&inside_outside=&fric_yn=&image_yn=&gubun=&kdc=&ttsUseYn=&l_sub_code=&fsearchMethod=search&sflag=1&isFDetailSearch=N&pageNumber=1&resultKeyword=&fsearchSort=&fsearchOrder=&limiterList=&limiterListText=&facetList=&facetListText=&fsearchDB=&icate=bib_t&colName=bib_t&pageScale=10&isTab=Y&regnm=&dorg_storage=&language=&language_code=&clickKeyword=&relationKeyword=&query=%EC%A0%95%EB%B3%B4%EC%98%81%EC%9E%AC'.format(i)
    res = requests.get(url)

    # print(res.status_code)
    res.raise_for_status()
    soup = BeautifulSoup(res.text, 'lxml')

    cont = soup.find('div', attrs={'class':'srchResultListW'}).ul
    if not cont:
        continue
    rows = cont.find_all('li')
        
    for row in rows:
        # 논문 리스트 번호
        num = row.find('span', attrs={'class':'num'})
        if num:
            num = num.get_text().strip()
        else:
            continue
        
        # 논문 제목
        title = row.find('p', attrs={'class':'title'})
        if not title:
            continue
        # 링크
        link = 'http://www.riss.kr' + title.find('a')['href']
        
        title = row.a.get_text()
        
        
        
        # 기타 등등
        etc = row.find('p', attrs={'class':'etc'})
        etc = etc.find_all('span')
        if not etc:
            continue
        writer = etc[0].a.get_text()                    # 논문 저자
        if etc[1].a:
            assigned = etc[1].a.get_text()                  # 승인 기관
        else:
            continue
        
        year = etc[2].get_text()                        # 년도
        degree = etc[3].get_text()                      # 학위
        
        # print(num, title, writer, assigned, year, degree, link)
        # 논문 제목에 '머신러닝' 키워드가 없는 것 제외
        if '영재' not in title:
            continue
        csv_writer.writerow([num, title, writer, assigned, year, degree, link])  

f.close()

# %%
# 인공지능 연구보고서
import requests
from bs4 import BeautifulSoup
import csv

# 1. csv 파일 생성
file_name = 'aipaper.csv'
f = open(file_name, 'w', encoding='utf-8-sig', newline='')
csv_writer = csv.writer(f)

for i in range(0, 100, 100):
    url = 'http://www.riss.kr/search/Search.do?isDetailSearch=N&searchGubun=true&viewYn=OP&queryText=&strQuery=%EC%A0%95%EB%B3%B4%EC%98%81%EC%9E%AC&exQuery=&exQueryText=&order=%2FDESC&onHanja=false&strSort=RANK&p_year1=&p_year2=&iStartCount=0&orderBy=&mat_type=&mat_subtype=&fulltext_kind=&t_gubun=&learning_type=&ccl_code=&inside_outside=&fric_yn=&image_yn=&gubun=&kdc=&ttsUseYn=&l_sub_code=&fsearchMethod=search&sflag=1&isFDetailSearch=N&pageNumber=1&resultKeyword=&fsearchSort=&fsearchOrder=&limiterList=&limiterListText=&facetList=&facetListText=&fsearchDB=&icate=re_t&colName=re_t&pageScale=100&isTab=Y&regnm=&dorg_storage=&language=&language_code=&clickKeyword=&relationKeyword=&query=%EC%9D%B8%EA%B3%B5%EC%A7%80%EB%8A%A5+%EA%B5%90%EC%9C%A1'
    res = requests.get(url)

    # print(res.status_code)
    res.raise_for_status()
    soup = BeautifulSoup(res.text, 'lxml')

    cont = soup.find('div', attrs={'class':'srchResultListW'}).ul
    if not cont:
        continue
    rows = cont.find_all('li')
        
    for row in rows:
        # 논문 리스트 번호
        num = row.find('span', attrs={'class':'num'})
        if num:
            num = num.get_text().strip()
        else:
            continue
        
        # 논문 제목
        title = row.find('p', attrs={'class':'title'})
        if not title:
            continue
        # 링크
        link = 'http://www.riss.kr' + title.find('a')['href']
        
        title = row.a.get_text()
        
        
        
        # 기타 등등
        etc = row.find('p', attrs={'class':'etc'})
        etc = etc.find_all('span')
        if not etc:
            continue
        writer = etc[0].a.get_text()                    # 논문 저자
        if etc[1].a:
            assigned = etc[1].a.get_text()                  # 승인 기관
        else:
            assigned = ''
        
        if len(etc)<=2:
            continue
        
        year = etc[2].get_text()                        # 년도
        if len(etc)>3:
            degree = etc[3].get_text()                      # 학위
        else:
            degree = ''
        
        # print(num, title, writer, assigned, year, degree, link)
        # 논문 제목에 '머신러닝' 키워드가 없는 것 제외
        if '인공지능' not in title:
            continue
        csv_writer.writerow([num, title, writer, assigned, year, degree, link])  

f.close()
