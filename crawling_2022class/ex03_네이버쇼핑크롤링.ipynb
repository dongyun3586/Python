# %%
# (실습 1) 네이버 쇼핑에서 ‘노트북’ 상품 정보 가져오기
import requests
from bs4 import BeautifulSoup
import re

url = 'https://search.shopping.naver.com/search/all'\
    '?query=%EB%85%B8%ED%8A%B8%EB%B6%81&cat_id=&frm=NVSHATC'
# headers = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36'

res = requests.get(url)
print(res.status_code)
res.raise_for_status()
soup = BeautifulSoup(res.text, 'lxml')

# print(res.text)
with open('shopping.html', 'w', encoding='utf8') as f:
    # f.write(res.text)
    f.write(soup.prettify())    # html 문서를 예쁘게 출력
# Out:
# 200

# %%
# (실습 2) ‘노트북’ 상품명, 가격, 평점, 리뷰수 가져오기
import requests
from bs4 import BeautifulSoup
import re

url = 'https://search.shopping.naver.com/search/all?query=%EB%85%B8%ED%8A%B8%EB%B6%81&frm=NVSHATC&prevQuery=%EB%85%B8%ED%8A%B8%EB%B6%81'
# 태블릿PC : https://search.shopping.naver.com/search/all?query=%ED%85%8C%EB%B8%94%EB%A6%BFPC&frm=NVSHATC&prevQuery=%ED%85%8C%EB%B8%94%EB%A6%BFPC
# 딸기 : https://search.shopping.naver.com/search/all?query=%EB%94%B8%EA%B8%B0&frm=NVSHATC&prevQuery=%ED%85%8C%EB%B8%94%EB%A6%BFPC

res = requests.get(url)
print(res.status_code)
res.raise_for_status()
soup = BeautifulSoup(res.text, 'lxml')

items = soup.find_all('li', attrs={'class':'basicList_item__2XT81'})
print('상품 개수:', len(items))

for i in items:
    name = i.find('a', attrs={'class':'basicList_link__1MaTN'}).get_text()                                  # 제품명
    price = i.find('span', attrs={'class':'price_num__2WUXn'}).get_text()                                   # 가격
    rating = i.find('span', attrs={'class':'basicList_star__3NkBn'}).get_text().replace('별점', '').strip() # 평점
    review_count = i.find('em', attrs={'class':'basicList_num__1yXM9'}).get_text()                          # 리뷰수
    print(name, price, rating, review_count)
# Out:
# 200
# 상품 개수: 5
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21944/3624249803.py in <module>
#      19     name = i.find('a', attrs={'class':'basicList_link__1MaTN'}).get_text()                                  # 제품명
#      20     price = i.find('span', attrs={'class':'price_num__2WUXn'}).get_text()                                   # 가격
# ---> 21     rating = i.find('span', attrs={'class':'basicList_star__3NkBn'}).get_text().replace('별점', '').strip() # 평점
#      22     review_count = i.find('em', attrs={'class':'basicList_num__1yXM9'}).get_text()                          # 리뷰수
#      23     print(name, price, rating, review_count)
#
# AttributeError: 'NoneType' object has no attribute 'get_text'

# %%
# (실습 2) ‘노트북’ 상품명, 가격, 평점, 리뷰수 가져오기
import requests
from bs4 import BeautifulSoup
import re

url = 'https://search.shopping.naver.com/search/all?query=%EB%85%B8%ED%8A%B8%EB%B6%81&frm=NVSHATC&prevQuery=%EB%85%B8%ED%8A%B8%EB%B6%81'
headers = 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36'

res = requests.get(url, headers)
# print(res.status_code)
res.raise_for_status()
soup = BeautifulSoup(res.text, 'lxml')

items = soup.find_all('li', attrs={'class':'basicList_item__2XT81'})
print('상품 개수:', len(items))

# 파일로 저장
with open('shopping.html', 'w', encoding='utf8') as f:
    f.write(soup.prettify())   

for i in items:
    name = i.find('a', attrs={'class':'basicList_link__1MaTN'}).get_text()                                  # 제품명
    price = i.find('span', attrs={'class':'price_num__2WUXn'}).get_text()                                   # 가격
    rating = i.find('span', attrs={'class':'basicList_star__3NkBn'})                                        # 평점
    if rating:
        rating = rating.get_text().replace('별점', '').strip()
    else:
        rating = '별점없음'
    review_count = i.find('em', attrs={'class':'basicList_num__1yXM9'}).get_text()                          # 리뷰수
    print(name, price, rating, review_count)
# Out:
# 200
# 상품 개수: 5
# 삼성전자 갤럭시북2 프로360 NT950QED-K71A 2,199,880원 별점없음 0
# 삼성전자 갤럭시북2 프로360 NT950QEW-A51A 1,899,000원 별점없음 0
# MSI Vector GP76 12UGS QHD 2,499,000원 4.1 20
# 삼성 노트북 플러스2 업무용 재택근무 저렴한 인강용 사무용 싼 가성비 노트북 한컴오피스 499,000원 별점없음 2,872
# 삼성전자 갤럭시북 프로360 NT950QDY-A51A 1,449,000원 4.9 3,993

# %%
from selenium import webdriver

driver = webdriver.Chrome()
driver.get("http://www.python.org")

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time

driver = webdriver.Chrome()
driver.get("http://www.python.org")
assert "Python" in driver.title
elem = driver.find_element(By.NAME, "q")
elem.clear()
elem.send_keys("pycon")
elem.send_keys(Keys.RETURN)
assert "No results found." not in driver.page_source
time.sleep(5)
driver.close()

# %%
# (실습 3) 동적 페이지 => selenium으로 페이지 맨 아랫부분까지 스크롤 내리기
from selenium import webdriver
driver = webdriver.Chrome()
driver.maximize_window()
driver.get("https://search.shopping.naver.com/search/all?query=%EB%85%B8%ED%8A%B8%EB%B6%81&frm=NVSHATC&prevQuery=%EB%85%B8%ED%8A%B8%EB%B6%81") 
import time

SCROLL_PAUSE_TIME = 1

# Get scroll height => 현재 문서의 높이 저장
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom => 현재 문서의 높이만큼 스크롤 내리기
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

print('스크롤 내리기 성공')

driver.close()
# Out:
# 스크롤 내리기 성공

# %%
# (실습 4) 현재 페이지의 상품 정보 출력하기
from selenium import webdriver
driver = webdriver.Chrome()
driver.maximize_window()
driver.get("https://search.shopping.naver.com/search/all?query=%EB%85%B8%ED%8A%B8%EB%B6%81&frm=NVSHATC&prevQuery=%EB%85%B8%ED%8A%B8%EB%B6%81") 
import time
from bs4 import BeautifulSoup
import re

#region 1. 화면 제일 아래까지 스크롤 내리기
SCROLL_PAUSE_TIME = 1

# Get scroll height => 현재 문서의 높이 저장
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom => 현재 문서의 높이만큼 스크롤 내리기
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

#endregion

# print(driver.page_source)
soup = BeautifulSoup(driver.page_source, 'lxml')

items = soup.find_all('li', attrs={'class':'basicList_item__2XT81'})
print('상품 개수:', len(items))

for i in items:
    name = i.find('a', attrs={'class':'basicList_link__1MaTN'}).get_text()          # 제품명
    price = i.find('span', attrs={'class':'price_num__2WUXn'}).get_text()           # 가격
    rating = i.find('span', attrs={'class':'basicList_star__3NkBn'})                # 평점                          
    if rating:
        rating = rating.get_text().replace('별점', '').strip()
    else:
        print('평점 없는 상품 제외됨.')
        continue
    review_count = i.find('em', attrs={'class':'basicList_num__1yXM9'})              # 리뷰수
    if review_count:
        review_count = review_count.get_text().replace(',','').strip()
    else:
        print('리뷰수 없는 상품 제외')
        continue
# %%
# (실습 5) 광고 제품, Apple 제품 제외하기
from selenium import webdriver
driver = webdriver.Chrome()
driver.maximize_window()
driver.get("https://search.shopping.naver.com/search/all?query=%EB%85%B8%ED%8A%B8%EB%B6%81&frm=NVSHATC&prevQuery=%EB%85%B8%ED%8A%B8%EB%B6%81") 
import time
from bs4 import BeautifulSoup
import re

#region 1. 화면 제일 아래까지 스크롤 내리기
SCROLL_PAUSE_TIME = 1

# Get scroll height => 현재 문서의 높이 저장
last_height = driver.execute_script("return document.body.scrollHeight")

while True:
    # Scroll down to bottom => 현재 문서의 높이만큼 스크롤 내리기
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # Wait to load page
    time.sleep(SCROLL_PAUSE_TIME)

    # Calculate new scroll height and compare with last scroll height
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height:
        break
    last_height = new_height

#endregion

soup = BeautifulSoup(driver.page_source, 'lxml')

items = soup.find_all('li', attrs={'class':'basicList_item__2XT81'})
print('상품 개수:', len(items))

for i in items:
    # 광고 상품 제외하기
    is_ad_item = i.find('button', attrs={'class':'ad_ad_stk__12U34'})
    if is_ad_item:
        print('광고 상품 제외됨.')
        continue
    
    name = i.find('a', attrs={'class':'basicList_link__1MaTN'}).get_text()          # 제품명
    # Apple 제품 제외하기
    if "Apple" in name:
        print('Apple 상품 제외됨.')
        continue

    price = i.find('span', attrs={'class':'price_num__2WUXn'}).get_text()           # 가격
    rating = i.find('span', attrs={'class':'basicList_star__3NkBn'})                # 평점                          
    if rating:
        rating = rating.get_text().replace('별점', '').strip()
    else:
        print('평점 없는 상품 제외됨.')
        continue
    review_count = i.find('em', attrs={'class':'basicList_num__1yXM9'})              # 리뷰수
    if review_count:
        review_count = review_count.get_text().replace(',','').strip()
    else:
        print('리뷰수 없는 상품 제외')
        continue
    link = i.find('a', attrs={'class':'basicList_link__1MaTN'})['href']                                     # 링크
    print(name, price, rating, review_count, link)

driver.close()
# Out:
# 상품 개수: 46
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 평점 없는 상품 제외됨.
# 삼성전자 갤럭시북 프로360 NT950QDY-A51A 1,478,880원 4.9 3993 https://cr.shopping.naver.com/adcr.nhn?x=x74MbV7%2BsUPxlR2CprQvJf%2F%2F%2Fw%3D%3Ds2krv9toJV%2F3WhwcHCFsDWKwcZfQM5fMpLaVSSoNrqkEXtKWU5l2RZhzweonlysWaGX2ToXLQc%2BfPMrCRHqFd1GS1r51ieXSdZcxDoc7VDqHqkgmvLvKMtL9zYIaFiVMC%2BGb6mnq%2FaKqeM%2F4csjde58v%2BjB2erv%2BZ%2Brrs5VHOiTQgGE7%2BZatKjf5hEf1XctkKIaKMwavJpoZDPS%2BtNB7HTtjMLMF37IGTcafAkl8SUA1yVIMMNqLACnbjknB0qr9Ol8wdop9mD%2FPa0WMRPJ7Q%2Bcv%2BjB2erv%2BZ%2Brrs5VHOiTRLlIk0uAh1LVcUK1nkYRMYW0HPJrSnCf%2FAZTMcaR9dFnV7rj7GrYGFPYndo03%2FAH3PM%2FUATTY3ww1ZW0YmSnab70gTarnHUQInjLYbSm9FgC6UxJeah0Om0lkIOZtT9ZI8exnqpLIzFUKgXuMFD8WU9zvpoJ7aJDDWjI5uxVEMckqgUuXvTGTX4sQkBtWyn9c0uRAMCc1QhIinRv4nRt1BzzQIdpk%2B6fmrnUTlXZZMzBzjTcXwoVM8lrhL6igy83IiTL95M4bmJT3LQffu4g1iPm2V2WLj0oLfvtXSAq9jPg1QmAmnoJRdq4K9btjkCM0%3D&nvMid=26962413523&catId=50000151
# 삼성전자 갤럭시북 NT761XDZ-G78A 1,698,000원 5 1010 https://cr.shopping.naver.com/adcr.nhn?x=U1SfmUZd%2B39NmwKQeGPk5v%2F%2F%2Fw%3D%3DsCowoNjOF%2FFzd0YrOyb8GbB7cWPxxRQVot0OdVzdQl8D2JuB1xbdLlYSG9uR1HG3pCuaRTVT7t8fKweNbWTdUlL49KoY5Be5e%2FWaL9mhdM2GSVlU8469fLZxcnEZDcciv6GQZxMx9ogGPmhrsyHtXJd9%2BKy%2Fm0d%2BgYWHtEf61Jo5CNclKwvLyA%2Fys%2F%2FHPPaj
Dwm%2BqtcL%2F%2BsHW7V7DzFLG5aBSNVPibcnPME%2FoYkJAjL%2BQUGULCgXGe20gqwhd7lVd6Z%2BmZ5fvTALbBBPmfKLmnGLANk9TjQtjOEdf9xG%2FDMvYMpxGGflhv0GSCuh60rNoujdiiNe5Aky91pn4j%2FJgGGrLhs5bBSYrLuLGqyj6%2BaliRbY8Klyoiq%2BIQ3TV3rHJM06m8XkkoABSxxLFFekLTugQBvejbtDuYpE%2F6l0aC3z2iH4RxFqDh9e7F7CfU%2FOb6hOEdGBFy%2BPYa0TWGXGumApD6%2B6fQB9OmTofQ%2BvTT8AlxSYkXaLH96LNyv1p9f%2FAc8EleRBcle4NBZGUTwY9sD%2FAiiFscuHkH7B40HKGb1NmOoRBMBsXNQGXzjfbC%2BFUQB%2FrDAzm2q1KHRsHkfE%3D&nvMid=29313451618&catId=50000151
# 레노버 Slim3 14ALC R5 453,150원 4.7 743 https://cr.shopping.naver.com/adcr.nhn?x=kt1%2BNlbbbR7lLkBRQajoW%2F%2F%2F%2Fw%3D%3DsnoesWNz7JIv8yuG8IGHCD6u%2BK3VCWH89Ac2rTHsJTzn2m%2FfFa014Vbw4CyFgdKsafhab49jTAyIUcTvXaiQ6atdwo5GZ0d3wZJv%2FJdElw5MGrtMmvb3h6eVzdIi8EWA5bmjWa7AGnFT%2BMxbHMAeTMlVd6Z%2BmZ5fvTALbBBPmfKJ5bQDYB3cjT4MuysiedFUMzHkBx%2B%2Bo9Te%2BMHSTG2XuERtDwm%2BqtcL%2F%2BsHW7V7DzFLG5aBSNVPibcnPME%2FoYkJAjL%2BQUGULCgXGe20gqwhd7lVd6Z%2BmZ5fvTALbBBPmfKLmnGLANk9TjQtjOEdf9xG%2F0N%2FlXu%2FCQ4zOeQC%2B4EJ8vbNoujdiiNe5Aky91pn4j%2FJgGGrLhs5bBSYrLuLGqyj65ib8HXfM9cg%2FXUy6PEpRjbHJM06m8XkkoABSxxLFFem4%2F93AEd4ZKPa%2FYOdGAtU1u7zNYvQYnf6W6qfYKtF059IY4JTP74ANscXQNQdIvf7NLmhT9wp7nHzjmQpIhJBNramjBwCZI9AwCV4mCTWQmUGm5JZm6LTaFJY%2FfFLy5fDiscZhAONnMZK5ntVoRVTCA35CyMrpXQUt3%2FJvHupy5s1ITc7NlRPvorKrNyQBKaY%3D&nvMid=27395557522&catId=50000151

# %%
# 동적 페이지 selenium으로 페이지 맨 아랫부분까지 스크롤 내리기
from selenium import webdriver
driver = webdriver.Chrome()
driver.maximize_window()
import time
from bs4 import BeautifulSoup

item_list=[]
for page in range(1, 6):
    url = 'https://search.shopping.naver.com/search/all?frm=NVSHATC&origQuery=%EB%85%B8%ED%8A%B8%EB%B6%81&pagingIndex={}&pagingSize=40&productSet=total&query=%EB%85%B8%ED%8A%B8%EB%B6%81&sort=rel&timestamp=&viewType=list'.format(page)
    driver.get(url) 

    #region 1. 화면의 제일 아랫 부분까지 스크롤 내리기
    SCROLL_PAUSE_TIME = 1

    # Get scroll height => 현재 문서의 높이 저장
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        # Scroll down to bottom => 현재 문서의 높이만큼 스크롤 내리기
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait to load page
        time.sleep(SCROLL_PAUSE_TIME)

        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

    print('스크를 내리기 성공')
    #endregion

    # 2. 스크롤된 페이지 파싱
    soup = BeautifulSoup(driver.page_source, 'lxml')

    #region 3. 상품 정보 추출하기
    items = soup.find_all('li', attrs={'class':'basicList_item__2XT81'})    # 상품 정보
    print(len(items))

    for i in items:
        # 광고 상품 제외하기
        is_ad_item = i.find('button', attrs={'class':'ad_ad_stk__12U34'})
        if is_ad_item:
            print('광고 상품 제외됨.')
            continue
        
        name = i.find('a', attrs={'class':'basicList_link__1MaTN'}).get_text()          # 제품명
        # Apple 제품 제외하기
        if "Apple" in name:
            print('Apple 상품 제외됨.')
            continue
        
        price = i.find('span', attrs={'class':'price_num__2WUXn'}).get_text()           # 가격
        
        rating = i.find('span', attrs={'class':'basicList_star__3NkBn'})                # 평점                          
        if rating:
            rating = rating.get_text().replace('별점', '').strip()
        else:
            print('평점 없는 상품 제외됨.')
            continue
        
        review_count = i.find('em', attrs={'class':'basicList_num__1yXM9'})              # 리뷰수
        if review_count:
            review_count = review_count.get_text().replace(',','').strip()
        else:
            print('리뷰수 없는 상품 제외')
            continue
        
        link = i.find('a', attrs={'class':'basicList_link__1MaTN'})['href']                                     # 링크
        
        item_list.append(f'{name}, {price}, {rating}, {review_count}')
        #endregion
        
    time.sleep(1)
    
print(len(item_list))
driver.close()
# Out:
# 스크를 내리기 성공
# 46
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 평점 없는 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# Apple 상품 제외됨.
# 평점 없는 상품 제외됨.
# Apple 상품 제외됨.
# 스크를 내리기 성공
# 46
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 평점 없는 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 스크를 내리기 성공
# 46
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# Apple 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# Apple 상품 제외됨.
# 평점 없는 상품 제외됨.
# 평점 없는 상품 제외됨.
# Apple 상품 제외됨.
# Apple 상품 제외됨.
# 스크를 내리기 성공
# 46
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# Apple 상품 제외됨.
# Apple 상품 제외됨.
# 스크를 내리기 성공
# 46
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 평점 없는 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 평점 없는 상품 제외됨.
# 평점 없는 상품 제외됨.
# 184

# %%
# (실습 7) csv 파일로 저장하기
from selenium import webdriver
from bs4 import BeautifulSoup
import csv
import time

driver = webdriver.Chrome()
driver.maximize_window()

# csv 파일 생성
file_name = 'notebook.csv'
f = open(file_name, 'w', encoding='utf-8-sig', newline='')
writer = csv.writer(f)

for page in range(1, 6):
    url = 'https://search.shopping.naver.com/search/all?frm=NVSHATC&origQuery=%EB%85%B8%ED%8A%B8%EB%B6%81&pagingIndex={}'\
        '&pagingSize=40&productSet=total&query=%EB%85%B8%ED%8A%B8%EB%B6%81&sort=rel&timestamp=&viewType=list'.format(page)
    driver.get(url) 


    #region 화면의 제일 아랫 부분까지 스크롤 내리기
    SCROLL_PAUSE_TIME = 1

    # Get scroll height => 현재 문서의 높이 저장
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        # Scroll down to bottom => 현재 문서의 높이만큼 스크롤 내리기
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait to load page
        time.sleep(SCROLL_PAUSE_TIME)

        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

    print('스크를 내리기 성공')
    #endregion

    # 스크롤된 페이지 파싱
    soup = BeautifulSoup(driver.page_source, 'lxml')

    #region 상품 정보 추출하기
    items = soup.find_all('li', attrs={'class':'basicList_item__2XT81'})    # 상품 정보
    print(len(items))

    for i in items:
        # 광고 상품 제외하기
        is_ad_item = i.find('button', attrs={'class':'ad_ad_stk__12U34'})
        if is_ad_item:
            print('광고 상품 제외됨.')
            continue
        
        name = i.find('a', attrs={'class':'basicList_link__1MaTN'}).get_text()          # 제품명
        # Apple 제품 제외하기
        if "Apple" in name:
            print('Apple 상품 제외됨.')
            continue
        
        price = i.find('span', attrs={'class':'price_num__2WUXn'}).get_text()           # 가격
        
        rating = i.find('span', attrs={'class':'basicList_star__3NkBn'})                # 평점                          
        if rating:
            rating = rating.get_text().replace('별점', '').strip()
        else:
            print('평점 없는 상품 제외됨.')
            continue
        
        review_count = i.find('em', attrs={'class':'basicList_num__1yXM9'})              # 리뷰수
        if review_count:
            review_count = review_count.get_text().replace(',','').strip()
        else:
            print('리뷰수 없는 상품 제외')
            continue
        
        link = i.find('a', attrs={'class':'basicList_link__1MaTN'})['href']                                     # 링크

        # 상품정보 csv 파일에 쓰기
        writer.writerow([name, price, rating, review_count, link])   
    time.sleep(1)  
    #endregion

f.close()
driver.close()
# Out:
# 스크를 내리기 성공
# 46
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 평점 없는 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# Apple 상품 제외됨.
# 평점 없는 상품 제외됨.
# Apple 상품 제외됨.
# 스크를 내리기 성공
# 46
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 평점 없는 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 스크를 내리기 성공
# 46
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# Apple 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# Apple 상품 제외됨.
# 평점 없는 상품 제외됨.
# 평점 없는 상품 제외됨.
# Apple 상품 제외됨.
# Apple 상품 제외됨.
# 스크를 내리기 성공
# 46
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# Apple 상품 제외됨.
# Apple 상품 제외됨.
# 스크를 내리기 성공
# 46
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 평점 없는 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 평점 없는 상품 제외됨.
# 평점 없는 상품 제외됨.

# %%
# (실습 8) 제품 검색 조건 추가하기
from selenium import webdriver
import time
from bs4 import BeautifulSoup
import csv

driver = webdriver.Chrome()
driver.maximize_window()

# 1. csv 파일 생성
file_name = 'notebook.csv'
f = open(file_name, 'w', encoding='utf8', newline='')
writer = csv.writer(f)

for page in range(1, 6):
    url = 'https://search.shopping.naver.com/search/all?frm=NVSHATC&origQuery=%EB%85%B8%ED%8A%B8%EB%B6%81&pagingIndex={}'\
        '&pagingSize=40&productSet=total&query=%EB%85%B8%ED%8A%B8%EB%B6%81&sort=rel&timestamp=&viewType=list'.format(page)
    driver.get(url) 


    #region 2. 화면의 제일 아랫 부분까지 스크롤 내리기
    SCROLL_PAUSE_TIME = 1

    # Get scroll height => 현재 문서의 높이 저장
    last_height = driver.execute_script("return document.body.scrollHeight")

    while True:
        # Scroll down to bottom => 현재 문서의 높이만큼 스크롤 내리기
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

        # Wait to load page
        time.sleep(SCROLL_PAUSE_TIME)

        # Calculate new scroll height and compare with last scroll height
        new_height = driver.execute_script("return document.body.scrollHeight")
        if new_height == last_height:
            break
        last_height = new_height

    print('스크를 내리기 성공')
    #endregion

    # 3. 스크롤된 페이지 파싱
    soup = BeautifulSoup(driver.page_source, 'lxml')

    #region 4. 상품 정보 추출하기
    items = soup.find_all('li', attrs={'class':'basicList_item__2XT81'})    # 상품 정보
    print(len(items))

    for i in items:
        # 광고 상품 제외하기
        is_ad_item = i.find('button', attrs={'class':'ad_ad_stk__12U34'})
        if is_ad_item:
            print('광고 상품 제외됨.')
            continue
        
        name = i.find('a', attrs={'class':'basicList_link__1MaTN'}).get_text()          # 제품명
        # Apple 제품 제외하기
        if "Apple" in name:
            print('Apple 상품 제외됨.')
            continue
        
        price = i.find('span', attrs={'class':'price_num__2WUXn'}).get_text()           # 가격
        
        rating = i.find('span', attrs={'class':'basicList_star__3NkBn'})                # 평점                          
        if rating:
            rating = rating.get_text().replace('별점', '').strip()
        else:
            print('평점 없는 상품 제외됨.')
            continue
        
        review_count = i.find('em', attrs={'class':'basicList_num__1yXM9'})              # 리뷰수
        if review_count:
            review_count = review_count.get_text().replace(',','').strip()
        else:
            print('리뷰수 없는 상품 제외')
            continue
        
        link = i.find('a', attrs={'class':'basicList_link__1MaTN'})['href']                                     # 링크

        # 평점 4.5 이상, 리뷰수 500개 이상 제품만 저장하기
        if float(rating)>=4.5 and int(review_count)>=500:
            writer.writerow([name, price, rating, review_count, link])  
         
    time.sleep(1)  
    #endregion

f.close()
driver.close()
# Out:
# 스크를 내리기 성공
# 46
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 평점 없는 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# Apple 상품 제외됨.
# 평점 없는 상품 제외됨.
# Apple 상품 제외됨.
# 스크를 내리기 성공
# 46
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 평점 없는 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 스크를 내리기 성공
# 46
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# Apple 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# Apple 상품 제외됨.
# 평점 없는 상품 제외됨.
# 평점 없는 상품 제외됨.
# Apple 상품 제외됨.
# Apple 상품 제외됨.
# 스크를 내리기 성공
# 46
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# Apple 상품 제외됨.
# Apple 상품 제외됨.
# 스크를 내리기 성공
# 46
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 평점 없는 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 광고 상품 제외됨.
# 평점 없는 상품 제외됨.
# 평점 없는 상품 제외됨.
